# %% [markdown]
# # Python 简介

# %% [markdown]
# ## Python的诞生

# %% [markdown]
# ### Guido von Rossum
#
# "I wrote Python"
#
# ![von.jpg](attachment:von.jpg)

# %% [markdown]
# ### 1980年代的编程
#
# - 极其有限的运算资源 （128K RAM）
#
#
# - Fortran
# - Pascal
# - C
#
#
# - Shell

# %% [markdown]
# ### ABC语言
#
# ```
# HOW TO RETURN words document:
#    PUT {} IN collection
#    FOR line IN document:
#       FOR word IN split line:
#          IF word not.in collection:
#             INSERT word IN collection
#    RETURN collection
#
# ```

# %% [markdown]
# ### Monte Python's Flying Circus
#
# 1989年，为了打发圣诞节假期，Guido开始写Python语言的编译/解释器。他希望这个新的叫做Python的语言，能实现他的理念(一种C和shell之间，功能全面，易学易用，可拓展的语言)。
#
# 1991年，第一个Python编译器(同时也是解释器)诞生。它是用C语言实现的，并能够调用C库(.so文件)。从一出生，Python已经具有了：类(class)，函数(function)，异常处理(exception)，包括表(list)和词典(dictionary)在内的核心数据类型，以及模块(module)为基础的拓展系统。

# %% [markdown]
# ## Python的能力
#
# - 软件开发
#
#
# - 服务器开发
#
#
# - 科学计算
#
#
# - ……

# %% [markdown]
# ## Python的使用环境

# %% [markdown]
# ### 终端

# %% [markdown]
# ### 命令行

# %% [markdown]
# ### IPython

# %% [markdown]
# ### Jupyter Notebook

# %% [markdown]
# ### 集成开发环境

# %% [markdown]
# ## 开发环境搭建

# %% [markdown]
# ### 文本编辑器
#
# - Notepad++
#
#
# - Visual Studio Code
#
#
# - Atom

# %% [markdown]
# ### 解释器
#
# - www.python.org
#
#
# - 应该选择哪个版本？

# %% [markdown]
# ### The Python Package Index
#
# - https://pypi.org/
#
#
# - pip

# %% [markdown]
# ### conda
#
# - https://www.anaconda.com/
#
#
# - conda, Anaconda, miniconda
#
#
# - https://mirrors.tuna.tsinghua.edu.cn/help/anaconda/

# %% [raw]
# .condarc 文件
#
# channels:
#   - defaults
# show_channel_urls: true
# default_channels:
#   - https://mirrors.tuna.tsinghua.edu.cn/anaconda/pkgs/main
#   - https://mirrors.tuna.tsinghua.edu.cn/anaconda/pkgs/r
#   - https://mirrors.tuna.tsinghua.edu.cn/anaconda/pkgs/msys2
# custom_channels:
#   conda-forge: https://mirrors.tuna.tsinghua.edu.cn/anaconda/cloud
#   msys2: https://mirrors.tuna.tsinghua.edu.cn/anaconda/cloud
#   bioconda: https://mirrors.tuna.tsinghua.edu.cn/anaconda/cloud
#   menpo: https://mirrors.tuna.tsinghua.edu.cn/anaconda/cloud
#   pytorch: https://mirrors.tuna.tsinghua.edu.cn/anaconda/cloud
#   simpleitk: https://mirrors.tuna.tsinghua.edu.cn/anaconda/cloud

# %% [raw]
# 命令行
#
# 通过开始菜单启动 Anaconda Prompt
#
# conda config --add channels https://mirrors.tuna.tsinghua.edu.cn/anaconda/pkgs/main
#
# conda clean -i
#
# conda update conda

# %% [raw]
# pip 镜像
#
# pip install pip -U
#
# pip config set global.index-url https://pypi.tuna.tsinghua.edu.cn/simple

# %% [markdown]
# ## 牛刀小试：好用的计算器
#
# - 基本运算：整数、实数、复数的四则运算与幂运算
#
#
#
#
# - 数学库

# %%
a = 7 + 8j
b = 10 - 3j
print(a+b,a-b,a*b,a/b,a**b,a.real//b.imag, a.real%b.imag)
divmod(-a.real,b.imag)
# Out:
# (17+5j) (-3+11j) (94+59j) (0.4220183486238532+0.9266055045871558j) (33642236459.936447+234962386333.80432j) -3.0 -2.0
# (2.0, -1.0)

# %% [markdown]
# ![nzhs.jpg](nzhs.jpg)

# %% [markdown]
# ### 数学库
#
# - numbers
# - math
# - cmath
# - decimal
# - fractions
# - random
# - statistics
